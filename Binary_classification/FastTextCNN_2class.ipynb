# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# -*- coding: utf-8 -*-
"""
Created on Mon Feb 11 12:29:48 2019

@author: SLab
"""
import tensorflow as tf
import keras.callbacks
#import sys
import os
import pandas
from keras import backend as K
from keras.utils.vis_utils import plot_model
from keras import optimizers
from keras.models import Sequential
from keras.layers import  Dropout
#import keras
from scipy import interp
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import pandas
import keras
from keras import optimizers
from keras import backend as K
from keras import regularizers
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, Flatten
from keras.layers import Embedding, Conv1D, MaxPooling1D, GlobalMaxPooling1D 
from keras.utils import plot_model
from keras.preprocessing import sequence
from keras.preprocessing.text import Tokenizer
from keras.callbacks import EarlyStopping
from subprocess import check_output
from tqdm import tqdm
from nltk.corpus import stopwords
from nltk.tokenize import RegexpTokenizer 
from sklearn.metrics import precision_recall_fscore_support
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.model_selection import train_test_split
#from sklearn import cross_validation

import os, re, csv, math, codecs
from sklearn.metrics import classification_report
from sklearn.metrics import precision_recall_curve
import time
from sklearn.metrics import roc_curve

from sklearn.metrics import auc
from sklearn.metrics import average_precision_score

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
data_dir = '/content/drive/My Drive/Thesis'

# %% [markdown]
# # Class Metrics
# commented

# %%
# ==============================================================================
class Metrics(keras.callbacks.Callback):
    def on_train_begin(self, logs={}):
        self.confusion = []
        self.precision = []
        self.recall = []
        self.f1s = []
        self.kappa = []
        self.auc = []

    def on_epoch_end(self, epoch, logs={}):
      score = np.asarray(self.model.predict(self.validation_data[0]))
      predict = np.round(np.asarray(self.model.predict(self.validation_data[0])))
      predict2 = np.asarray(self.model.predict(self.validation_data[0]))
      #print("#######y_predict2s#####")
      #print(predict2)
      #print("#######y_predict#####")
      #print(predict)
      targ = self.validation_data[1]
      #print("#######targ#####")
      #print(targ)
      y_test_non_category = [ np.argmax(t) for t in targ ]
      y_predict_non_category = [ np.argmax(t) for t in predict ]
      y_predict_non_category2 = [ np.amax(t) for t in predict2 ]
      #print("#######y_predict_non_category2#####")
      #print(y_predict_non_category2)
      #print("#######y_test_non_category#####")
      #print(y_test_non_category)
      conf_mat = confusion_matrix(y_test_non_category, y_predict_non_category)
      print("########confusion_matrics########")
      print(conf_mat)
        #self.auc.append(sklm.roc_auc_score(targ, score))
#==============================================================================
#       self.confusion.append(confusion_matrix(y_test_non_category, y_predict_non_category))
#       print("confusion_matrics 2")
#       print(self.confusion)
#       
#==============================================================================
      report = classification_report(y_test_non_category,  y_predict_non_category, target_names=label_names)
      print("########classification report########")
      print(report) 
      
      fpr_keras, tpr_keras, thresholds_keras = roc_curve(y_test_non_category,  y_predict_non_category)
      auc_keras = auc(fpr_keras, tpr_keras)
      print("########ROC##########")
      print(auc_keras) 
      #self.classification_report.append(classification_report(y_test_non_category,  y_predict_non_category, target_names=label_names))
      self.precision.append(precision_score(y_test_non_category, y_predict_non_category,average='weighted'))
      self.recall.append(recall_score(y_test_non_category, y_predict_non_category,average='weighted'))
      #auc_PRC = auc(self.recall, self.precision)
#==============================================================================
      precision1, recall1, thresholds1 = precision_recall_curve(y_test_non_category, y_predict_non_category)
      print("########PRC##########")
      auc_PRC= auc(recall1, precision1)
      print(auc_PRC)
#==============================================================================
 # Compute ROC curve and ROC area for each class
      fpr = dict()
      tpr = dict()
      roc_auc = dict()
      n_classes=2
      for i in range(n_classes):
          fpr[i], tpr[i], _ = roc_curve(targ[:, i], predict[:, i])
          roc_auc[i] = auc(fpr[i], tpr[i])

# Compute micro-average ROC curve and ROC area
      fpr["micro"], tpr["micro"], _ = roc_curve(targ.ravel(), predict.ravel())
      roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

# Compute macro-average ROC curve and ROC area

# First aggregate all false positive rates
      all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))

# Then interpolate all ROC curves at this points
      mean_tpr = np.zeros_like(all_fpr)
      for i in range(n_classes):
          mean_tpr += interp(all_fpr, fpr[i], tpr[i])

# Finally average it and compute AUC
      mean_tpr /= n_classes

      fpr["macro"] = all_fpr
      tpr["macro"] = mean_tpr
      roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])
      print("########ROC_MAC##########")
      print(roc_auc) 
      n_classes=2
      precision = dict()
      recall = dict()
      average_precision = dict()
      for i in range(n_classes):
            precision[i], recall[i], _ = precision_recall_curve(targ[:, i],
                                                                predict[:, i])
            average_precision[i] = average_precision_score(targ[:, i], predict[:, i])
        
        # A "micro-average": quantifying score on all classes jointly
      precision["micro"], recall["micro"], _ = precision_recall_curve(targ.ravel(),
            predict.ravel())
      average_precision["macro"] = average_precision_score(targ, predict,
                                                             average="macro")
      average_precision["micro"] = average_precision_score(targ, predict,
                                                             average="micro")
      average_precision["weighted"] = average_precision_score(targ, predict,
                                                             average="weighted")
      print('Average precision score, Macro-averaged over all classes: {0:0.5f}' .format(average_precision["macro"]))
      print('Average precision score, Micro-averaged over all classes: {0:0.5f}' .format(average_precision["micro"]))
      print('Average precision score, Weighted-averaged over all classes: {0:0.5f}' .format(average_precision["weighted"]))
      
      return
# ==============================================================================

# %% [markdown]
# # Helping functions

# %%
def precision(y_true, y_pred):
    """Precision metric.

    Only computes a batch-wise average of precision.

    Computes the precision, a metric for multi-label classification of
    how many selected items are relevant.
    """
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

def recall(y_true, y_pred):
    """Recall metric.

    Only computes a batch-wise average of recall.

    Computes the recall, a metric for multi-label classification of
    how many relevant items are selected.
    """
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def f1(y_true, y_pred):
    def recall(y_true, y_pred):
        """Recall metric.

        Only computes a batch-wise average of recall.

        Computes the recall, a metric for multi-label classification of
        how many relevant items are selected.
        """
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
        recall = true_positives / (possible_positives + K.epsilon())
        return recall

    def precision(y_true, y_pred):
        """Precision metric.

        Only computes a batch-wise average of precision.

        Computes the precision, a metric for multi-label classification of
        how many selected items are relevant.
        """
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
        precision = true_positives / (predicted_positives + K.epsilon())
        return precision
    precision = precision(y_true, y_pred)
    recall = recall(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall))

def auc(y_true, y_pred):
    auc = tf.metrics.auc(y_true, y_pred)[1]
    K.get_session().run(tf.local_variables_initializer())
    return auc


from sklearn.metrics import roc_auc_score
def auroc(y_true, y_pred):
    return roc_auc_score(y_true, y_pred)

# auc = roc_auc_score(testy, yhat_probs)

from sklearn.metrics import cohen_kappa_score
def kappa(y_true, y_pred):
    cohen_kappa_score(y_true, y_pred)

# %%
sns.set_style("whitegrid")
np.random.seed(0)

DATA_PATH = '../input/'
EMBEDDING_DIR = '../input/'

MAX_NB_WORDS = 100000
tokenizer = RegexpTokenizer(r'\w+')
stop_words = set(stopwords.words('english'))
stop_words.update(['.', ',', '"', "'", ':', ';', '(', ')', '[', ']', '{', '}'])

class LossHistory(keras.callbacks.Callback):
    def on_train_begin(self, logs={}):
        self.losses = []
        self.accuracies = []

    def on_batch_end(self, batch, logs={}):
        self.losses.append(logs.get('loss'))
        self.accuracies.append(logs.get('acc'))
        
class TimeHistory(keras.callbacks.Callback):
    def on_train_begin(self, logs={}):
        self.times = []

    def on_epoch_begin(self, epoch, logs={}):
        self.epoch_time_start = time.time()

    def on_epoch_end(self, epoch, logs={}):
        self.times.append(time.time() - self.epoch_time_start)
        
#print(check_output(["ls", "../input"]).decode("utf8"))

print('loading word embeddings...')
embeddings_index = {}
f = codecs.open(data_dir + '/Embeddings/wiki.simple.vec', encoding='utf-8')
for line in tqdm(f):
    values = line.rstrip().rsplit(' ')
    word = values[0]
    coefs = np.asarray(values[1:], dtype='float32')
    embeddings_index[word] = coefs
f.close()

print('found %s word vectors' % len(embeddings_index))


train_df = pd.read_csv(data_dir + '/Data/Thesis_ACA_citation_data' + '/final_data_citations_B.csv', sep=',', header=0,encoding = "ISO-8859-1")
test_df = pd.read_csv(data_dir + '/Data/Thesis_ACA_citation_data' + '/final_data_citations_B_test.csv', sep=',', header=0,encoding = "ISO-8859-1")
test_df = test_df.fillna('_NA_')

print("num train: ", train_df.shape[0])
print("num test: ", test_df.shape[0])

label_names = ["positional", "essential"]
y_train = train_df[label_names].values

#visualize word distribution
train_df['doc_len'] = train_df['text'].apply(lambda words: len(words.split(" ")))
max_seq_len = np.round(train_df['doc_len'].mean() + train_df['doc_len'].std()).astype(int)
#print("####################################################")
#print(max_seq_len)
#==============================================================================
# sns.distplot(train_df['doc_len'], hist=True, kde=True, color='b', label='doc len')
# print("####################################################")
# plt.axvline(x=max_seq_len, color='k', linestyle='--', label='max len')
# plt.title('comment length'); plt.legend()
# plt.show()
#==============================================================================
raw_docs_train = train_df['text'].tolist()
raw_docs_test = test_df['text'].tolist() 
num_classes = len(label_names)

print("pre-processing train data...")
processed_docs_train = []
for doc in tqdm(raw_docs_train):
    tokens = tokenizer.tokenize(doc)
    filtered = [word for word in tokens if word not in stop_words]
    processed_docs_train.append(" ".join(filtered))
#end for

processed_docs_test = []
for doc in tqdm(raw_docs_test):
    tokens = tokenizer.tokenize(doc)
    filtered = [word for word in tokens if word not in stop_words]
    processed_docs_test.append(" ".join(filtered))
#end for

print("tokenizing input data...")
tokenizer = Tokenizer(num_words=MAX_NB_WORDS, lower=True, char_level=False)
tokenizer.fit_on_texts(processed_docs_train + processed_docs_test)  #leaky
word_seq_train = tokenizer.texts_to_sequences(processed_docs_train)
word_seq_test = tokenizer.texts_to_sequences(processed_docs_test)
word_index = tokenizer.word_index
print("dictionary size: ", len(word_index))

#pad sequences
word_seq_train = sequence.pad_sequences(word_seq_train, maxlen=max_seq_len)
word_seq_test = sequence.pad_sequences(word_seq_test, maxlen=max_seq_len)

random_state = np.random.RandomState(0)
X_train, X_test, Y_train, Y_test = train_test_split(word_seq_train, y_train, test_size=.2,
                                                    random_state=random_state)

#print (X_test)
#print("########################")
#print(Y_test)

batch_size = 256 
num_epochs = 100

#model parameters
num_filters = 64 
embed_dim = 300 
weight_decay = 1e-3

#embedding matrix
print('preparing embedding matrix...')
words_not_found = []
nb_words = min(MAX_NB_WORDS, len(word_index)+2)
embedding_matrix = np.zeros((nb_words, embed_dim))
for word, i in word_index.items():
    if i >= nb_words:
        continue
    embedding_vector = embeddings_index.get(word)
    if (embedding_vector is not None) and len(embedding_vector) > 0:
        # words not found in embedding index will be all-zeros.
        embedding_matrix[i] = embedding_vector
    else:
        words_not_found.append(word)
print('number of null word embeddings: %d' % np.sum(np.sum(embedding_matrix, axis=1) == 0))

print("sample words not found: ", np.random.choice(words_not_found, 10))

print("training CNN ...")
model = Sequential()
model.add(Embedding(nb_words, embed_dim,
          weights=[embedding_matrix], input_length=max_seq_len, trainable=False))
model.add(Conv1D(num_filters, 7, activation='relu', padding='same'))
model.add(MaxPooling1D(2))
model.add(Conv1D(num_filters, 7, activation='relu', padding='same'))
model.add(GlobalMaxPooling1D())
model.add(Dropout(0.3))
model.add(Dense(32, activation='relu', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Dense(num_classes, activation='sigmoid'))  #multi-label (k-hot encoding)

class_weight = {0: 1,
                1: 9}
#class_weight=class_weight
history = LossHistory()
time_callback = TimeHistory()
#metrics = Metrics()
#keras.optimizers.Adam(lr=0.001)
adam = optimizers.Adam(lr=0.0001)
#, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0
model.compile(loss='binary_crossentropy', optimizer=adam, metrics=['accuracy',precision,recall, f1])
model.summary()
early_stopping = EarlyStopping(monitor='val_loss', min_delta=0.01, patience=4, verbose=1)
callbacks_list = [early_stopping]
pandas.DataFrame( model.fit(X_train, Y_train, validation_data=(X_test, Y_test), 
                                  batch_size=256,class_weight=class_weight, epochs=100, shuffle=True, verbose=2, callbacks=[history,time_callback]).history).to_csv("fullData-ClassWeight0.5-Adam_B_001.csv")

print("Binaryclass-fullData-classweight-done")
# Out:
# 904it [00:00, 9037.92it/s]
# loading word embeddings...
# 111052it [00:13, 8404.12it/s]
# found 111052 word vectors
#  15%|█▍        | 1401/9518 [00:00<00:00, 14002.54it/s]
# num train:  9518
# num test:  520
# pre-processing train data...
# 100%|██████████| 9518/9518 [00:00<00:00, 18040.39it/s]
# 100%|██████████| 520/520 [00:00<00:00, 47235.20it/s]
# tokenizing input data...
# dictionary size:  25519
# preparing embedding matrix...
# number of null word embeddings: 12772
# sample words not found:  ['gottron' 'event2' 'planarity' 'stipulations' 'generalizeâ' 'diminum'
#  'schuhmann' 'binot' 'it13' 'entence']
# training CNN ...
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 213, 300)          7656300
# _________________________________________________________________
# conv1d (Conv1D)              (None, 213, 64)           134464
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 106, 64)           0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 106, 64)           28736
# _________________________________________________________________
# global_max_pooling1d (Global (None, 64)                0
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# dense (Dense)                (None, 32)                2080
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 66
# =================================================================
# Total params: 7,821,646
# Trainable params: 165,346
# Non-trainable params: 7,656,300
# _________________________________________________________________
# Epoch 1/100
# 30/30 - 29s - loss: 1.3740 - accuracy: 0.2602 - precision: 0.3167 - recall: 0.3341 - f1: 0.3240 - val_loss: 0.7149 - val_accuracy: 0.8403 - val_precision: 0.8085 - val_recall: 0.4587 - val_f1: 0.5849
# Epoch 2/100
# 30/30 - 28s - loss: 1.3218 - accuracy: 0.5708 - precision: 0.5506 - recall: 0.4954 - f1: 0.5212 - val_loss: 0.7078 - val_accuracy: 0.8650 - val_precision: 0.8323 - val_recall: 0.6725 - val_f1: 0.7438
# Epoch 3/100
# 30/30 - 28s - loss: 1.3063 - accuracy: 0.6164 - precision: 0.5754 - recall: 0.5561 - f1: 0.5652 - val_loss: 0.7154 - val_accuracy: 0.7705 - val_precision: 0.7904 - val_recall: 0.5465 - val_f1: 0.6455
# Epoch 4/100
# 30/30 - 28s - loss: 1.2920 - accuracy: 0.6292 - precision: 0.5909 - recall: 0.5910 - f1: 0.5904 - val_loss: 0.7020 - val_accuracy: 0.7784 - val_precision: 0.7821 - val_recall: 0.6937 - val_f1: 0.7351
# Epoch 5/100
# 30/30 - 28s - loss: 1.2726 - accuracy: 0.5575 - precision: 0.5413 - recall: 0.5377 - f1: 0.5393 - val_loss: 0.6739 - val_accuracy: 0.8304 - val_precision: 0.8151 - val_recall: 0.8019 - val_f1: 0.8084
# Epoch 6/100
# 30/30 - 28s - loss: 1.2508 - accuracy: 0.6623 - precision: 0.6332 - recall: 0.6376 - f1: 0.6349 - val_loss: 0.7236 - val_accuracy: 0.5000 - val_precision: 0.5267 - val_recall: 0.4007 - val_f1: 0.4550
# Epoch 7/100
# 30/30 - 28s - loss: 1.2177 - accuracy: 0.5939 - precision: 0.5824 - recall: 0.6021 - f1: 0.5918 - val_loss: 0.6695 - val_accuracy: 0.7038 - val_precision: 0.7244 - val_recall: 0.6498 - val_f1: 0.6850
# Epoch 8/100
# 30/30 - 28s - loss: 1.1947 - accuracy: 0.6307 - precision: 0.6127 - recall: 0.6333 - f1: 0.6227 - val_loss: 0.6549 - val_accuracy: 0.7059 - val_precision: 0.6915 - val_recall: 0.7005 - val_f1: 0.6959
# Epoch 9/100
# 30/30 - 28s - loss: 1.1517 - accuracy: 0.6471 - precision: 0.6247 - recall: 0.6590 - f1: 0.6413 - val_loss: 0.6007 - val_accuracy: 0.7820 - val_precision: 0.7808 - val_recall: 0.7751 - val_f1: 0.7779
# Epoch 10/100
# 30/30 - 28s - loss: 1.1162 - accuracy: 0.6812 - precision: 0.6681 - recall: 0.6940 - f1: 0.6807 - val_loss: 0.6180 - val_accuracy: 0.7264 - val_precision: 0.7208 - val_recall: 0.7215 - val_f1: 0.7211
# Epoch 11/100
# 30/30 - 28s - loss: 1.0689 - accuracy: 0.6949 - precision: 0.6815 - recall: 0.7115 - f1: 0.6961 - val_loss: 0.5909 - val_accuracy: 0.7595 - val_precision: 0.7505 - val_recall: 0.7480 - val_f1: 0.7492
# Epoch 12/100
# 30/30 - 28s - loss: 1.0289 - accuracy: 0.7342 - precision: 0.7163 - recall: 0.7457 - f1: 0.7306 - val_loss: 0.5849 - val_accuracy: 0.7553 - val_precision: 0.7510 - val_recall: 0.7463 - val_f1: 0.7486
# Epoch 13/100
# 30/30 - 29s - loss: 0.9802 - accuracy: 0.7652 - precision: 0.7418 - recall: 0.7789 - f1: 0.7598 - val_loss: 0.5790 - val_accuracy: 0.7521 - val_precision: 0.7407 - val_recall: 0.7521 - val_f1: 0.7464
# Epoch 14/100
# 30/30 - 28s - loss: 0.9369 - accuracy: 0.7842 - precision: 0.7652 - recall: 0.7884 - f1: 0.7765 - val_loss: 0.5655 - val_accuracy: 0.7663 - val_precision: 0.7636 - val_recall: 0.7477 - val_f1: 0.7556
# Epoch 15/100
# 30/30 - 28s - loss: 0.8910 - accuracy: 0.8086 - precision: 0.7908 - recall: 0.8185 - f1: 0.8043 - val_loss: 0.5531 - val_accuracy: 0.7663 - val_precision: 0.7644 - val_recall: 0.7404 - val_f1: 0.7522
# Epoch 16/100
# 30/30 - 28s - loss: 0.8435 - accuracy: 0.8188 - precision: 0.7996 - recall: 0.8257 - f1: 0.8124 - val_loss: 0.6210 - val_accuracy: 0.6717 - val_precision: 0.6706 - val_recall: 0.6541 - val_f1: 0.6622
# Epoch 17/100
# 30/30 - 28s - loss: 0.8213 - accuracy: 0.8269 - precision: 0.8135 - recall: 0.8374 - f1: 0.8252 - val_loss: 0.6253 - val_accuracy: 0.6618 - val_precision: 0.6645 - val_recall: 0.6468 - val_f1: 0.6555
# Epoch 18/100
# 30/30 - 28s - loss: 0.7650 - accuracy: 0.8416 - precision: 0.8279 - recall: 0.8440 - f1: 0.8358 - val_loss: 0.5335 - val_accuracy: 0.7736 - val_precision: 0.7581 - val_recall: 0.7590 - val_f1: 0.7585
# Epoch 19/100
# 30/30 - 29s - loss: 0.7291 - accuracy: 0.8582 - precision: 0.8446 - recall: 0.8628 - f1: 0.8536 - val_loss: 0.5037 - val_accuracy: 0.7952 - val_precision: 0.7891 - val_recall: 0.7940 - val_f1: 0.7915
# Epoch 20/100
# 30/30 - 29s - loss: 0.6996 - accuracy: 0.8629 - precision: 0.8502 - recall: 0.8711 - f1: 0.8605 - val_loss: 0.4541 - val_accuracy: 0.8340 - val_precision: 0.8232 - val_recall: 0.8339 - val_f1: 0.8285
# Epoch 21/100
# 30/30 - 29s - loss: 0.6408 - accuracy: 0.8909 - precision: 0.8792 - recall: 0.8954 - f1: 0.8871 - val_loss: 0.4637 - val_accuracy: 0.8241 - val_precision: 0.8134 - val_recall: 0.8296 - val_f1: 0.8214
# Epoch 22/100
# 30/30 - 29s - loss: 0.6187 - accuracy: 0.8878 - precision: 0.8828 - recall: 0.8888 - f1: 0.8858 - val_loss: 0.4178 - val_accuracy: 0.8561 - val_precision: 0.8457 - val_recall: 0.8478 - val_f1: 0.8467
# Epoch 23/100
# 30/30 - 29s - loss: 0.5875 - accuracy: 0.9012 - precision: 0.8928 - recall: 0.9026 - f1: 0.8976 - val_loss: 0.4573 - val_accuracy: 0.8225 - val_precision: 0.8107 - val_recall: 0.8235 - val_f1: 0.8170
# Epoch 24/100
# 30/30 - 29s - loss: 0.5648 - accuracy: 0.9015 - precision: 0.8924 - recall: 0.9049 - f1: 0.8986 - val_loss: 0.4103 - val_accuracy: 0.8508 - val_precision: 0.8454 - val_recall: 0.8475 - val_f1: 0.8464
# Epoch 25/100
# 30/30 - 29s - loss: 0.5182 - accuracy: 0.9173 - precision: 0.9096 - recall: 0.9192 - f1: 0.9143 - val_loss: 0.3511 - val_accuracy: 0.8818 - val_precision: 0.8755 - val_recall: 0.8817 - val_f1: 0.8786
# Epoch 26/100
# 30/30 - 29s - loss: 0.4822 - accuracy: 0.9276 - precision: 0.9211 - recall: 0.9301 - f1: 0.9256 - val_loss: 0.3735 - val_accuracy: 0.8718 - val_precision: 0.8640 - val_recall: 0.8670 - val_f1: 0.8655
# Epoch 27/100
# 30/30 - 29s - loss: 0.4638 - accuracy: 0.9283 - precision: 0.9217 - recall: 0.9302 - f1: 0.9259 - val_loss: 0.3430 - val_accuracy: 0.8824 - val_precision: 0.8757 - val_recall: 0.8806 - val_f1: 0.8781
# Epoch 28/100
# 30/30 - 29s - loss: 0.4427 - accuracy: 0.9312 - precision: 0.9270 - recall: 0.9297 - f1: 0.9283 - val_loss: 0.4034 - val_accuracy: 0.8524 - val_precision: 0.8433 - val_recall: 0.8462 - val_f1: 0.8447
# Epoch 29/100
# 30/30 - 29s - loss: 0.4206 - accuracy: 0.9350 - precision: 0.9318 - recall: 0.9368 - f1: 0.9343 - val_loss: 0.3453 - val_accuracy: 0.8803 - val_precision: 0.8732 - val_recall: 0.8749 - val_f1: 0.8740
# Epoch 30/100
# 30/30 - 29s - loss: 0.3779 - accuracy: 0.9464 - precision: 0.9448 - recall: 0.9451 - f1: 0.9449 - val_loss: 0.3403 - val_accuracy: 0.8803 - val_precision: 0.8757 - val_recall: 0.8753 - val_f1: 0.8755
# Epoch 31/100
# 30/30 - 29s - loss: 0.3679 - accuracy: 0.9540 - precision: 0.9494 - recall: 0.9532 - f1: 0.9513 - val_loss: 0.3596 - val_accuracy: 0.8729 - val_precision: 0.8666 - val_recall: 0.8679 - val_f1: 0.8673
# Epoch 32/100
# 30/30 - 29s - loss: 0.3496 - accuracy: 0.9488 - precision: 0.9467 - recall: 0.9509 - f1: 0.9488 - val_loss: 0.3279 - val_accuracy: 0.8845 - val_precision: 0.8790 - val_recall: 0.8794 - val_f1: 0.8792
# Epoch 33/100
# 30/30 - 29s - loss: 0.3336 - accuracy: 0.9555 - precision: 0.9535 - recall: 0.9560 - f1: 0.9547 - val_loss: 0.3127 - val_accuracy: 0.8908 - val_precision: 0.8865 - val_recall: 0.8891 - val_f1: 0.8878
# Epoch 34/100
# 30/30 - 29s - loss: 0.3243 - accuracy: 0.9560 - precision: 0.9522 - recall: 0.9553 - f1: 0.9537 - val_loss: 0.3726 - val_accuracy: 0.8661 - val_precision: 0.8603 - val_recall: 0.8590 - val_f1: 0.8597
# Epoch 35/100
# 30/30 - 29s - loss: 0.2952 - accuracy: 0.9605 - precision: 0.9574 - recall: 0.9596 - f1: 0.9585 - val_loss: 0.3126 - val_accuracy: 0.8908 - val_precision: 0.8838 - val_recall: 0.8856 - val_f1: 0.8847
# Epoch 36/100
# 30/30 - 29s - loss: 0.2844 - accuracy: 0.9662 - precision: 0.9633 - recall: 0.9666 - f1: 0.9649 - val_loss: 0.3097 - val_accuracy: 0.8944 - val_precision: 0.8881 - val_recall: 0.8916 - val_f1: 0.8898
# Epoch 37/100
# 30/30 - 28s - loss: 0.2804 - accuracy: 0.9641 - precision: 0.9626 - recall: 0.9644 - f1: 0.9635 - val_loss: 0.3246 - val_accuracy: 0.8871 - val_precision: 0.8796 - val_recall: 0.8841 - val_f1: 0.8819
# Epoch 38/100
# 30/30 - 29s - loss: 0.2540 - accuracy: 0.9699 - precision: 0.9675 - recall: 0.9693 - f1: 0.9684 - val_loss: 0.3151 - val_accuracy: 0.8902 - val_precision: 0.8844 - val_recall: 0.8870 - val_f1: 0.8857
# Epoch 39/100
# 30/30 - 28s - loss: 0.2416 - accuracy: 0.9714 - precision: 0.9708 - recall: 0.9716 - f1: 0.9712 - val_loss: 0.3060 - val_accuracy: 0.8960 - val_precision: 0.8912 - val_recall: 0.8921 - val_f1: 0.8916
# Epoch 40/100
# 30/30 - 28s - loss: 0.2368 - accuracy: 0.9707 - precision: 0.9708 - recall: 0.9706 - f1: 0.9707 - val_loss: 0.3129 - val_accuracy: 0.8939 - val_precision: 0.8867 - val_recall: 0.8916 - val_f1: 0.8891
# Epoch 41/100
# 30/30 - 28s - loss: 0.2224 - accuracy: 0.9744 - precision: 0.9737 - recall: 0.9758 - f1: 0.9747 - val_loss: 0.3079 - val_accuracy: 0.8976 - val_precision: 0.8932 - val_recall: 0.8937 - val_f1: 0.8934
# Epoch 42/100
# 30/30 - 28s - loss: 0.2203 - accuracy: 0.9745 - precision: 0.9729 - recall: 0.9745 - f1: 0.9737 - val_loss: 0.3060 - val_accuracy: 0.8992 - val_precision: 0.8972 - val_recall: 0.8982 - val_f1: 0.8977
# Epoch 43/100
# 30/30 - 28s - loss: 0.2081 - accuracy: 0.9773 - precision: 0.9769 - recall: 0.9782 - f1: 0.9775 - val_loss: 0.3082 - val_accuracy: 0.8981 - val_precision: 0.8915 - val_recall: 0.8951 - val_f1: 0.8933
# Epoch 44/100
# 30/30 - 29s - loss: 0.1955 - accuracy: 0.9792 - precision: 0.9793 - recall: 0.9796 - f1: 0.9795 - val_loss: 0.3124 - val_accuracy: 0.8965 - val_precision: 0.8920 - val_recall: 0.8926 - val_f1: 0.8923
# Epoch 45/100
# 30/30 - 30s - loss: 0.2011 - accuracy: 0.9782 - precision: 0.9780 - recall: 0.9780 - f1: 0.9780 - val_loss: 0.3069 - val_accuracy: 0.9018 - val_precision: 0.8981 - val_recall: 0.8987 - val_f1: 0.8984
# Epoch 46/100
# 30/30 - 28s - loss: 0.1902 - accuracy: 0.9791 - precision: 0.9784 - recall: 0.9793 - f1: 0.9788 - val_loss: 0.3155 - val_accuracy: 0.8971 - val_precision: 0.8916 - val_recall: 0.8926 - val_f1: 0.8921
# Epoch 47/100
# 30/30 - 29s - loss: 0.1845 - accuracy: 0.9806 - precision: 0.9807 - recall: 0.9808 - f1: 0.9808 - val_loss: 0.3100 - val_accuracy: 0.9013 - val_precision: 0.8976 - val_recall: 0.8977 - val_f1: 0.8976
# Epoch 48/100
# 30/30 - 29s - loss: 0.1697 - accuracy: 0.9838 - precision: 0.9833 - recall: 0.9841 - f1: 0.9837 - val_loss: 0.3199 - val_accuracy: 0.8955 - val_precision: 0.8900 - val_recall: 0.8927 - val_f1: 0.8913
# Epoch 49/100
# 30/30 - 30s - loss: 0.1759 - accuracy: 0.9828 - precision: 0.9823 - recall: 0.9819 - f1: 0.9821 - val_loss: 0.3085 - val_accuracy: 0.9107 - val_precision: 0.9052 - val_recall: 0.9070 - val_f1: 0.9061
# Epoch 50/100
# 30/30 - 29s - loss: 0.1737 - accuracy: 0.9849 - precision: 0.9848 - recall: 0.9847 - f1: 0.9847 - val_loss: 0.3202 - val_accuracy: 0.8950 - val_precision: 0.8900 - val_recall: 0.8932 - val_f1: 0.8916
# Epoch 51/100
# 30/30 - 29s - loss: 0.1557 - accuracy: 0.9853 - precision: 0.9852 - recall: 0.9864 - f1: 0.9858 - val_loss: 0.3166 - val_accuracy: 0.8981 - val_precision: 0.8931 - val_recall: 0.8940 - val_f1: 0.8936
# Epoch 52/100
# 30/30 - 29s - loss: 0.1536 - accuracy: 0.9853 - precision: 0.9849 - recall: 0.9857 - f1: 0.9853 - val_loss: 0.3152 - val_accuracy: 0.9023 - val_precision: 0.8994 - val_recall: 0.8986 - val_f1: 0.8990
# Epoch 53/100
# 30/30 - 29s - loss: 0.1544 - accuracy: 0.9845 - precision: 0.9839 - recall: 0.9852 - f1: 0.9846 - val_loss: 0.3148 - val_accuracy: 0.9076 - val_precision: 0.9024 - val_recall: 0.9045 - val_f1: 0.9034
# Epoch 54/100
# 30/30 - 29s - loss: 0.1480 - accuracy: 0.9869 - precision: 0.9871 - recall: 0.9871 - f1: 0.9871 - val_loss: 0.3189 - val_accuracy: 0.9007 - val_precision: 0.8970 - val_recall: 0.8966 - val_f1: 0.8968
# Epoch 55/100
# 30/30 - 29s - loss: 0.1360 - accuracy: 0.9882 - precision: 0.9882 - recall: 0.9885 - f1: 0.9883 - val_loss: 0.3192 - val_accuracy: 0.9076 - val_precision: 0.9031 - val_recall: 0.9036 - val_f1: 0.9033
# Epoch 56/100
# 30/30 - 29s - loss: 0.1376 - accuracy: 0.9894 - precision: 0.9892 - recall: 0.9904 - f1: 0.9898 - val_loss: 0.3193 - val_accuracy: 0.9049 - val_precision: 0.9013 - val_recall: 0.8990 - val_f1: 0.9002
# Epoch 57/100
# 30/30 - 28s - loss: 0.1319 - accuracy: 0.9883 - precision: 0.9878 - recall: 0.9883 - f1: 0.9880 - val_loss: 0.3200 - val_accuracy: 0.9070 - val_precision: 0.9025 - val_recall: 0.9011 - val_f1: 0.9018
# Epoch 58/100
# 30/30 - 28s - loss: 0.1290 - accuracy: 0.9888 - precision: 0.9890 - recall: 0.9891 - f1: 0.9890 - val_loss: 0.3259 - val_accuracy: 0.9060 - val_precision: 0.9021 - val_recall: 0.9026 - val_f1: 0.9024
# Epoch 59/100
# 30/30 - 29s - loss: 0.1223 - accuracy: 0.9911 - precision: 0.9908 - recall: 0.9914 - f1: 0.9911 - val_loss: 0.3270 - val_accuracy: 0.9065 - val_precision: 0.9013 - val_recall: 0.9036 - val_f1: 0.9024
# Epoch 60/100
# 30/30 - 29s - loss: 0.1311 - accuracy: 0.9892 - precision: 0.9886 - recall: 0.9892 - f1: 0.9889 - val_loss: 0.3284 - val_accuracy: 0.8997 - val_precision: 0.8971 - val_recall: 0.8976 - val_f1: 0.8974
# Epoch 61/100
# 30/30 - 28s - loss: 0.1217 - accuracy: 0.9900 - precision: 0.9897 - recall: 0.9902 - f1: 0.9900 - val_loss: 0.3289 - val_accuracy: 0.9070 - val_precision: 0.9032 - val_recall: 0.9041 - val_f1: 0.9036
# Epoch 62/100
# 30/30 - 28s - loss: 0.1153 - accuracy: 0.9919 - precision: 0.9914 - recall: 0.9921 - f1: 0.9917 - val_loss: 0.3253 - val_accuracy: 0.9039 - val_precision: 0.8986 - val_recall: 0.9026 - val_f1: 0.9006
# Epoch 63/100
# 30/30 - 29s - loss: 0.1129 - accuracy: 0.9925 - precision: 0.9922 - recall: 0.9921 - f1: 0.9922 - val_loss: 0.3279 - val_accuracy: 0.9023 - val_precision: 0.8979 - val_recall: 0.9006 - val_f1: 0.8993
# Epoch 64/100
# 30/30 - 29s - loss: 0.1127 - accuracy: 0.9920 - precision: 0.9910 - recall: 0.9913 - f1: 0.9912 - val_loss: 0.3334 - val_accuracy: 0.9060 - val_precision: 0.9022 - val_recall: 0.9026 - val_f1: 0.9024
# Epoch 65/100
# 30/30 - 29s - loss: 0.1094 - accuracy: 0.9920 - precision: 0.9915 - recall: 0.9915 - f1: 0.9915 - val_loss: 0.3313 - val_accuracy: 0.9044 - val_precision: 0.9003 - val_recall: 0.9016 - val_f1: 0.9010
# Epoch 66/100
# 30/30 - 29s - loss: 0.1077 - accuracy: 0.9907 - precision: 0.9907 - recall: 0.9907 - f1: 0.9907 - val_loss: 0.3312 - val_accuracy: 0.9039 - val_precision: 0.8997 - val_recall: 0.9002 - val_f1: 0.8999
# Epoch 67/100
# 30/30 - 29s - loss: 0.1062 - accuracy: 0.9917 - precision: 0.9917 - recall: 0.9924 - f1: 0.9921 - val_loss: 0.3320 - val_accuracy: 0.9028 - val_precision: 0.8984 - val_recall: 0.9016 - val_f1: 0.9000
# Epoch 68/100
# 30/30 - 29s - loss: 0.1086 - accuracy: 0.9915 - precision: 0.9914 - recall: 0.9915 - f1: 0.9915 - val_loss: 0.3335 - val_accuracy: 0.9060 - val_precision: 0.9012 - val_recall: 0.9016 - val_f1: 0.9014
# Epoch 69/100
# 30/30 - 29s - loss: 0.1061 - accuracy: 0.9905 - precision: 0.9902 - recall: 0.9906 - f1: 0.9904 - val_loss: 0.3383 - val_accuracy: 0.9065 - val_precision: 0.9026 - val_recall: 0.9031 - val_f1: 0.9029
# Epoch 70/100
# 30/30 - 29s - loss: 0.0996 - accuracy: 0.9926 - precision: 0.9926 - recall: 0.9935 - f1: 0.9930 - val_loss: 0.3387 - val_accuracy: 0.9034 - val_precision: 0.8992 - val_recall: 0.8992 - val_f1: 0.8992
# Epoch 71/100
# 30/30 - 29s - loss: 0.1007 - accuracy: 0.9923 - precision: 0.9921 - recall: 0.9921 - f1: 0.9921 - val_loss: 0.3385 - val_accuracy: 0.9055 - val_precision: 0.9012 - val_recall: 0.9021 - val_f1: 0.9017
# Epoch 72/100
# 30/30 - 29s - loss: 0.0999 - accuracy: 0.9928 - precision: 0.9921 - recall: 0.9930 - f1: 0.9926 - val_loss: 0.3428 - val_accuracy: 0.9081 - val_precision: 0.9049 - val_recall: 0.9031 - val_f1: 0.9040
# Epoch 73/100
# 30/30 - 29s - loss: 0.0915 - accuracy: 0.9945 - precision: 0.9947 - recall: 0.9946 - f1: 0.9947 - val_loss: 0.3439 - val_accuracy: 0.9049 - val_precision: 0.9017 - val_recall: 0.9026 - val_f1: 0.9021
# Epoch 74/100
# 30/30 - 29s - loss: 0.0964 - accuracy: 0.9941 - precision: 0.9941 - recall: 0.9941 - f1: 0.9941 - val_loss: 0.3427 - val_accuracy: 0.9081 - val_precision: 0.9040 - val_recall: 0.9036 - val_f1: 0.9038
# Epoch 75/100
# 30/30 - 29s - loss: 0.0946 - accuracy: 0.9941 - precision: 0.9935 - recall: 0.9937 - f1: 0.9936 - val_loss: 0.3476 - val_accuracy: 0.9070 - val_precision: 0.9035 - val_recall: 0.9031 - val_f1: 0.9033
# Epoch 76/100
# 30/30 - 29s - loss: 0.0965 - accuracy: 0.9933 - precision: 0.9932 - recall: 0.9932 - f1: 0.9932 - val_loss: 0.3432 - val_accuracy: 0.9028 - val_precision: 0.8993 - val_recall: 0.9002 - val_f1: 0.8997
# Epoch 77/100
# 30/30 - 29s - loss: 0.0912 - accuracy: 0.9941 - precision: 0.9941 - recall: 0.9943 - f1: 0.9942 - val_loss: 0.3436 - val_accuracy: 0.8992 - val_precision: 0.8950 - val_recall: 0.8945 - val_f1: 0.8947
# Epoch 78/100
# 30/30 - 29s - loss: 0.0951 - accuracy: 0.9928 - precision: 0.9920 - recall: 0.9929 - f1: 0.9925 - val_loss: 0.3475 - val_accuracy: 0.9065 - val_precision: 0.9026 - val_recall: 0.9021 - val_f1: 0.9023
# Epoch 79/100
# 30/30 - 29s - loss: 0.0861 - accuracy: 0.9947 - precision: 0.9947 - recall: 0.9945 - f1: 0.9946 - val_loss: 0.3566 - val_accuracy: 0.9086 - val_precision: 0.9040 - val_recall: 0.9036 - val_f1: 0.9038
# Epoch 80/100
# 30/30 - 29s - loss: 0.0883 - accuracy: 0.9937 - precision: 0.9938 - recall: 0.9941 - f1: 0.9939 - val_loss: 0.3579 - val_accuracy: 0.9102 - val_precision: 0.9059 - val_recall: 0.9045 - val_f1: 0.9052
# Epoch 81/100
# 30/30 - 29s - loss: 0.0905 - accuracy: 0.9933 - precision: 0.9938 - recall: 0.9936 - f1: 0.9937 - val_loss: 0.3771 - val_accuracy: 0.9139 - val_precision: 0.9099 - val_recall: 0.9094 - val_f1: 0.9097
# Epoch 82/100
# 30/30 - 29s - loss: 0.0900 - accuracy: 0.9932 - precision: 0.9931 - recall: 0.9932 - f1: 0.9931 - val_loss: 0.3514 - val_accuracy: 0.9076 - val_precision: 0.9039 - val_recall: 0.9026 - val_f1: 0.9032
# Epoch 83/100
# 30/30 - 28s - loss: 0.0818 - accuracy: 0.9954 - precision: 0.9954 - recall: 0.9950 - f1: 0.9952 - val_loss: 0.3567 - val_accuracy: 0.9065 - val_precision: 0.9034 - val_recall: 0.9016 - val_f1: 0.9025
# Epoch 84/100
# 30/30 - 28s - loss: 0.0792 - accuracy: 0.9944 - precision: 0.9937 - recall: 0.9941 - f1: 0.9939 - val_loss: 0.3543 - val_accuracy: 0.9044 - val_precision: 0.9012 - val_recall: 0.9021 - val_f1: 0.9017
# Epoch 85/100
# 30/30 - 29s - loss: 0.0797 - accuracy: 0.9947 - precision: 0.9950 - recall: 0.9946 - f1: 0.9948 - val_loss: 0.3613 - val_accuracy: 0.9055 - val_precision: 0.9025 - val_recall: 0.9016 - val_f1: 0.9021
# Epoch 86/100
# 30/30 - 28s - loss: 0.0782 - accuracy: 0.9955 - precision: 0.9954 - recall: 0.9958 - f1: 0.9956 - val_loss: 0.3602 - val_accuracy: 0.9060 - val_precision: 0.9008 - val_recall: 0.9021 - val_f1: 0.9014
# Epoch 87/100
# 30/30 - 29s - loss: 0.0890 - accuracy: 0.9925 - precision: 0.9927 - recall: 0.9924 - f1: 0.9925 - val_loss: 0.3530 - val_accuracy: 0.9049 - val_precision: 0.9016 - val_recall: 0.9016 - val_f1: 0.9016
# Epoch 88/100
# 30/30 - 29s - loss: 0.0808 - accuracy: 0.9944 - precision: 0.9942 - recall: 0.9946 - f1: 0.9944 - val_loss: 0.3658 - val_accuracy: 0.9081 - val_precision: 0.9045 - val_recall: 0.9036 - val_f1: 0.9040
# Epoch 89/100
# 30/30 - 29s - loss: 0.0829 - accuracy: 0.9942 - precision: 0.9942 - recall: 0.9939 - f1: 0.9940 - val_loss: 0.3527 - val_accuracy: 0.9055 - val_precision: 0.9020 - val_recall: 0.9025 - val_f1: 0.9022
# Epoch 90/100
# 30/30 - 29s - loss: 0.0821 - accuracy: 0.9928 - precision: 0.9927 - recall: 0.9928 - f1: 0.9927 - val_loss: 0.3720 - val_accuracy: 0.9112 - val_precision: 0.9073 - val_recall: 0.9055 - val_f1: 0.9064
# Epoch 91/100
# 30/30 - 29s - loss: 0.0820 - accuracy: 0.9945 - precision: 0.9944 - recall: 0.9942 - f1: 0.9943 - val_loss: 0.3762 - val_accuracy: 0.9076 - val_precision: 0.9048 - val_recall: 0.9031 - val_f1: 0.9040
# Epoch 92/100
# 30/30 - 29s - loss: 0.0749 - accuracy: 0.9957 - precision: 0.9956 - recall: 0.9960 - f1: 0.9958 - val_loss: 0.3623 - val_accuracy: 0.9065 - val_precision: 0.9035 - val_recall: 0.9026 - val_f1: 0.9030
# Epoch 93/100
# 30/30 - 29s - loss: 0.0749 - accuracy: 0.9955 - precision: 0.9955 - recall: 0.9954 - f1: 0.9954 - val_loss: 0.3668 - val_accuracy: 0.9060 - val_precision: 0.9025 - val_recall: 0.9021 - val_f1: 0.9023
# Epoch 94/100
# 30/30 - 29s - loss: 0.0706 - accuracy: 0.9957 - precision: 0.9957 - recall: 0.9957 - f1: 0.9957 - val_loss: 0.3663 - val_accuracy: 0.9044 - val_precision: 0.9016 - val_recall: 0.9016 - val_f1: 0.9016
# Epoch 95/100
# 30/30 - 29s - loss: 0.0748 - accuracy: 0.9958 - precision: 0.9956 - recall: 0.9953 - f1: 0.9954 - val_loss: 0.3641 - val_accuracy: 0.9065 - val_precision: 0.9027 - val_recall: 0.9031 - val_f1: 0.9029
# Epoch 96/100
# 30/30 - 29s - loss: 0.0726 - accuracy: 0.9957 - precision: 0.9954 - recall: 0.9955 - f1: 0.9954 - val_loss: 0.3737 - val_accuracy: 0.9070 - val_precision: 0.9035 - val_recall: 0.9026 - val_f1: 0.9030
# Epoch 97/100
# 30/30 - 29s - loss: 0.0715 - accuracy: 0.9962 - precision: 0.9959 - recall: 0.9964 - f1: 0.9961 - val_loss: 0.3775 - val_accuracy: 0.9055 - val_precision: 0.9025 - val_recall: 0.9016 - val_f1: 0.9021
# Epoch 98/100
# 30/30 - 29s - loss: 0.0711 - accuracy: 0.9951 - precision: 0.9950 - recall: 0.9951 - f1: 0.9951 - val_loss: 0.3706 - val_accuracy: 0.9060 - val_precision: 0.9022 - val_recall: 0.9026 - val_f1: 0.9024
# Epoch 99/100
# 30/30 - 29s - loss: 0.0774 - accuracy: 0.9953 - precision: 0.9953 - recall: 0.9953 - f1: 0.9953 - val_loss: 0.3806 - val_accuracy: 0.9060 - val_precision: 0.9026 - val_recall: 0.9026 - val_f1: 0.9026
# Epoch 100/100
# 30/30 - 29s - loss: 0.0661 - accuracy: 0.9965 - precision: 0.9967 - recall: 0.9967 - f1: 0.9967 - val_loss: 0.3760 - val_accuracy: 0.9060 - val_precision: 0.9016 - val_recall: 0.9011 - val_f1: 0.9014
# Binaryclass-fullData-classweight-done
